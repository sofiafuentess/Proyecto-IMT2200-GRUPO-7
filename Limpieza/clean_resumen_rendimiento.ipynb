# %% [markdown]
# # Limpieza de datos de resumen de rendimiento escolar
#
# En este cuaderno de Jupyter, se limpiará los datos ligados al resumen de rendimiento académico escolar por colegio.
#
# El conjunto de datos utilizado en este análisis se encuentra en el archivo "Resumen_Rendimiento_Estudiante.csv", el cual contiene información sobre el rendimiento de los estudiantes en diferentes escuelas de Chile. El conjunto de datos incluye información  el RBD de la escuela, y los porcentajes de asistencia de los alumnos aprobados/reprovados por escuela

# %%
#importación de librerias 
import pandas as pd

# %%
# cargar el archivo como un df de pandas
df = pd.read_csv('data/Resumen_Rendimiento.csv', sep=';')

# %%
# cargar el archivo como un df de pandas
df
# Out:
#        AGNO    RBD  DGV_RBD  \
# 0      2022      1        9
# 1      2022      1        9
# 2      2022      1        9
# 3      2022      1        9
# 4      2022      1        9
# ...     ...    ...      ...
# 13727  2022  42071        9
# 13728  2022  42081        6
# 13729  2022  42081        6
# 13730  2022  42130        8
# 13731  2022  42130        8
#
#                                                  NOM_RBD  COD_REG_RBD  \
# 0                                LICEO POLITECNICO ARICA           15
# 1                                LICEO POLITECNICO ARICA           15
# 2                                LICEO POLITECNICO ARICA           15
# 3                                LICEO POLITECNICO ARICA           15
# 4                                LICEO POLITECNICO ARICA           15
# ...                                                  ...          ...
# 13727   INSTITUTO DE EDUCACIÓN DE ADULTOS MONTAÑA NEVADA           10
# 13728                    ESCUELA HOSPITALARIA SANTA CRUZ            6
# 13729                    ESCUELA HOSPITALARIA SANTA CRUZ            6
# 13730  ESCUELA HOSPITALARIA PROVINCIA CORDILLERA PUEN...           13
# 13731  ESCUELA HOSPITALARIA PROVINCIA CORDILLERA PUEN...           13
#
#       NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD  NOM_COM_RBD  COD_DEPROV_RBD  \
# 0               AYP          151        15101        ARICA             151
# 1               AYP          151        15101        ARICA             151
# 2               AYP          151        15101        ARICA             151
# 3               AYP          151        15101        ARICA             151
# 4               AYP          151        15101        ARICA             151
# ...             ...          ...          ...          ...             ...
# 13727         LAGOS          103        10301       OSORNO             103
# 13728          LGBO           63         6310   SANTA CRUZ              62
# 13729          LGBO           63         6310   SANTA CRUZ              62
# 13730            RM          132        13201  PUENTE ALTO             136
# 13731            RM          132        13201  PUENTE ALTO             136
#
#        ... SI_MUJ_08  SI_MUJ_TO  PROM_ASIS_APR_HOM  PROM_ASIS_APR_MUJ  \
# 0      ...         0          0               91,5               91,2
# 1      ...         0          0   90,0037453183521   90,4943820224719
# 2      ...         0          0   91,4324324324324   94,9565217391304
# 3      ...         0          0   90,4782608695652    91,536231884058
# 4      ...         0          0              89,25           91,96875
# ...    ...       ...        ...                ...                ...
# 13727  ...         0          0                 87                 86
# 13728  ...         0          0                 85               87,5
# 13729  ...         0          0   86,6666666666667                 90
# 13730  ...         0          4
# 13731  ...         0          0
#
#        PROM_ASIS_APR_SI     PROM_ASIS_APR  PROM_ASIS_REP_HOM  \
# 0                        91,2857142857143
# 1                         90,126404494382               67,5
# 2                        92,7833333333333                 62
# 3                        91,2717391304348
# 4                        91,6666666666667
# ...                 ...               ...                ...
# 13727                    86,3333333333333                 50
# 13728                    86,6666666666667
# 13729                                  88
# 13730
# 13731
#
#        PROM_ASIS_REP_MUJ     PROM_ASIS_REP         PROM_ASIS
# 0                                           91,2857142857143
# 1                   73,4             68,68  88,7191601049869
# 2                   55,5  61,1333333333333  86,4533333333333
# 3                     85                85  91,0736842105263
# 4                     50                50  90,5405405405405
# ...                  ...               ...               ...
# 13727             49,375  49,4444444444444  58,6666666666667
# 13728                                       86,6666666666667
# 13729                                                     88
# 13730
# 13731
#
# [13732 rows x 122 columns]

# %% [markdown]
# ### 2.1 Columnas a utilizar
# Las columnas que utilizaremos en este cuaderno de Jupyter son las siguientes:
#
# - `RBD`: Codigo unico del establecimiento
# - `NOM_RBD`: Nombre del establecimiento
# - `COD_COM_RBD`: Código de la comuna
# - `COD_PRO_RBD`: Código de la provincia
# - `PROM_ASIS`: Porcentaje promedio de Asistencia de
# los alumnos de un mismo nivel de Enseñanza
# - `PROM_ASIS_REP6`: Porcentaje promedio de Asistencia de los alumnos reprobados de un mismo
# nivel de Enseñanza

# %%
# Filtramos únicamente las columnas nesesarias
columnas = ['RBD', 'NOM_RBD', 'COD_COM_RBD', 'COD_PRO_RBD', 'PROM_ASIS', 'PROM_ASIS_REP']
df = df[columnas]
df.head()
# Out:
#    RBD                  NOM_RBD  COD_COM_RBD  COD_PRO_RBD         PROM_ASIS  \
# 0    1  LICEO POLITECNICO ARICA        15101          151  91,2857142857143
# 1    1  LICEO POLITECNICO ARICA        15101          151  88,7191601049869
# 2    1  LICEO POLITECNICO ARICA        15101          151  86,4533333333333
# 3    1  LICEO POLITECNICO ARICA        15101          151  91,0736842105263
# 4    1  LICEO POLITECNICO ARICA        15101          151  90,5405405405405
#
#       PROM_ASIS_REP
# 0
# 1             68,68
# 2  61,1333333333333
# 3                85
# 4                50
